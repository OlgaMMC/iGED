# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt

# %%
def significant_corr(df,a,b):
  import scipy.stats as stats
  r = stats.pearsonr(df[a], df[b])
  if r[1] < 0.1:
    return (True,r[0])
  else:
    return (False,0)

def print_significant_corr(df,a,b):
  import scipy.stats as stats
  r = stats.pearsonr(df[a], df[b])
  if r[1] < 0.1:
    print(f'Correlation between:  ' + a + '   and   ' + b)
    print('**********************************************')
    print(f'Pearson Correlation: {r[0]}, p-value: {r[1]}')
    print('*Statistically significant*')
    print('***********************************************')

# %%
ieco_grf_df=pd.read_csv('iEco_&_graph.csv')
ieco_df=pd.read_csv('iEco.csv')
grf_df=pd.read_csv('../Tidy_DataFrame.csv')

# %%
list1=list(ieco_df.keys())
list2=list(grf_df.keys())

list2.remove('Ciudad')
list2.remove('País')
list2.remove('Menciones')

positive_pairs=[]
negative_pairs=[]

for key1 in list1:
    for key2 in list2:
        sig,corr=significant_corr(ieco_grf_df,key1,key2)
        if sig==True:
            if corr>0:
                positive_pairs.append((key1,key2))
            else:
                negative_pairs.append((key1,key2))

# %%
for keys in positive_pairs:
    print_significant_corr(ieco_grf_df,keys[0],keys[1])
    print('')
    print('')
# Out:
# Correlation between:  Unnamed: 0   and   Modularidad con pesos (0.8)
# **********************************************
# Pearson Correlation: 0.9070035925942317, p-value: 0.012570365792290258
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  Unnamed: 0   and   Small Worldness
# **********************************************
# Pearson Correlation: 0.732069037671541, p-value: 0.09806352078811444
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.02 I-Funding   and   Diámetro
# **********************************************
# Pearson Correlation: 0.7385065695777545, p-value: 0.09362791589032411
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.04 I-Demand   and   avg strength
# **********************************************
# Pearson Correlation: 0.952116314101418, p-value: 0.00338437607108655
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.04 I-Demand   and   Modularidad sin pesos (1.0)
# **********************************************
# Pearson Correlation: 0.734259553485187, p-value: 0.09654394994934125
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.05 I-Culture & Incentives   and   avg strength
# **********************************************
# Pearson Correlation: 0.857666917638727, p-value: 0.028946317443073532
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.05 I-Culture & Incentives   and   Eccentricidad
# **********************************************
# Pearson Correlation: 0.8042285278880069, p-value: 0.05373808928218256
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.05 I-Culture & Incentives   and   Modularidad sin pesos (1.0)
# **********************************************
# Pearson Correlation: 0.7295465786128893, p-value: 0.0998264147703644
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.05 I-Culture & Incentives   and   Diámetro
# **********************************************
# Pearson Correlation: 0.8885028029536859, p-value: 0.017954391755494337
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  2.05 I-Culture & Incentives   and   Radio
# **********************************************
# Pearson Correlation: 0.9596725168103402, p-value: 0.0024066664386883847
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.02 E-Funding   and   avg strength
# **********************************************
# Pearson Correlation: 0.8339687441974102, p-value: 0.03906112668446363
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   avg strength
# **********************************************
# Pearson Correlation: 0.8088411132847811, p-value: 0.051319942701221276
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   Eccentricidad
# **********************************************
# Pearson Correlation: 0.8281029252267336, p-value: 0.04178324715066623
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   Modularidad sin pesos (0.8)
# **********************************************
# Pearson Correlation: 0.966806006086117, p-value: 0.0016344745923585645
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   Modularidad sin pesos (1.0)
# **********************************************
# Pearson Correlation: 0.9769691883189484, p-value: 0.0007895194481956441
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   Modularidad sin pesos (1.2)
# **********************************************
# Pearson Correlation: 0.9813465895666313, p-value: 0.0005186793567174707
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  3.04 E-Demand   and   Camino más corto promedio
# **********************************************
# Pearson Correlation: 0.8298911750732905, p-value: 0.04094429789577112
# *Statistically significant*
# ***********************************************
#
#
# Correlation between:  4 Comparative Advantage   and   avg strength
# **********************************************
# Pearson Correlation: 0.7546943496725862, p-value: 0.08288167628557128
# *Statistically significant*
# ***********************************************

# %%
for keys in negative_pairs:
    print_significant_corr(ieco_grf_df,keys[0],keys[1])
# Out:
# Correlation between:  2.04 I-Demand   and   weight
# **********************************************
# Pearson Correlation: -0.7513026741395321, p-value: 0.08508453028112797
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   indegree
# **********************************************
# Pearson Correlation: -0.7930354359599854, p-value: 0.05981890185570923
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   outdegree
# **********************************************
# Pearson Correlation: -0.7930354359599854, p-value: 0.05981890185570923
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   Degree
# **********************************************
# Pearson Correlation: -0.7930354359599853, p-value: 0.059818901855709296
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   weighted indegree
# **********************************************
# Pearson Correlation: -0.7540324234088824, p-value: 0.0833095479157745
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   weighted outdegree
# **********************************************
# Pearson Correlation: -0.7540324234088824, p-value: 0.0833095479157745
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   Weighted Degree
# **********************************************
# Pearson Correlation: -0.7540324234088824, p-value: 0.0833095479157745
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   Clustering
# **********************************************
# Pearson Correlation: -0.9174944429171862, p-value: 0.00992993587365419
# *Statistically significant*
# ***********************************************
# Correlation between:  2.04 I-Demand   and   Transitividad
# **********************************************
# Pearson Correlation: -0.859276309400167, p-value: 0.028311348968014967
# *Statistically significant*
# ***********************************************
# Correlation between:  2.05 I-Culture & Incentives   and   Eficiencia Global
# **********************************************
# Pearson Correlation: -0.7580202266991896, p-value: 0.08074684871617822
# *Statistically significant*
# ***********************************************
# Correlation between:  3.01 E-Human Capital   and   Modularidad con pesos (1.2)
# **********************************************
# Pearson Correlation: -0.7639984575575787, p-value: 0.07697283519015112
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   weight
# **********************************************
# Pearson Correlation: -0.9463687283104188, p-value: 0.004237339784452611
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   indegree
# **********************************************
# Pearson Correlation: -0.9626246701606462, p-value: 0.0020692678362156935
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   outdegree
# **********************************************
# Pearson Correlation: -0.9626246701606462, p-value: 0.0020692678362156935
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   Degree
# **********************************************
# Pearson Correlation: -0.9626246701606462, p-value: 0.0020692678362156935
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   weighted indegree
# **********************************************
# Pearson Correlation: -0.9496417749365054, p-value: 0.003740073255955904
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   weighted outdegree
# **********************************************
# Pearson Correlation: -0.9496417749365054, p-value: 0.003740073255955904
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   Weighted Degree
# **********************************************
# Pearson Correlation: -0.9496417749365054, p-value: 0.003740073255955904
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   Clustering
# **********************************************
# Pearson Correlation: -0.8980342032527662, p-value: 0.015065465156441013
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   Transitividad
# **********************************************
# Pearson Correlation: -0.9712565321782048, p-value: 0.001227406674736705
# *Statistically significant*
# ***********************************************
# Correlation between:  3.04 E-Demand   and   Eficiencia Global
# **********************************************
# Pearson Correlation: -0.912144555017792, p-value: 0.011238809213837436
# *Statistically significant*
# ***********************************************
